# %% [markdown]
# # Intro & Setup
#
# Initialize your first chat with a model.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("How much is the weight of the Earth?")

response
# Out:
# AIMessage(content="The phrase “weight of the Earth” is a bit ambiguous. Weight is a force due to gravity, so you have to specify the gravity source.\n\n- Earth's mass (the common meaning): about 5.97 × 10^24 kilograms.\n- If you mean the gravitational force the Sun exerts on Earth (i.e., Earth’s weight in the Sun’s gravity): about 3.5 × 10^22 newtons.\n  - This comes from F = GM_sun m_earth / r^2 ≈ 3.54 × 10^22 N, with r ≈ 1 AU.\n\nIf you had a different reference gravity in mind (e.g., weight on another planet), tell me and I can compute that too.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1507, 'prompt_tokens': 15, 'total_tokens': 1522, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1344, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DSQcWlVusR3cJpYem2Yp6B9taRCzV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6e0d-adcb-7ab1-8fbb-66756bdfec3f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 1507, 'total_tokens': 1522, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1344}})

# %%
print(response.content)
# Out:
# Weight is the force due to gravity on an object. For a planet, it’s not a single fixed value, but we can give its mass and, if desired, the external gravitational pull.
#
# - Mass of the Earth: about 5.97 × 10^24 kilograms (roughly 5.97 septillion kg; about 6 × 10^21 metric tons).
#
# - If you want a “weight” in a gravitational field: the Earth is held in orbit mainly by the Sun’s gravity, which exerts about 3.5 × 10^22 newtons on the Earth at 1 AU.
#
# - Note: If you tried to assign a weight to the Earth in its own gravity, that isn’t meaningful—the Earth’s gravity is what it itself produces. Weight is defined relative to an external gravitational field.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DSPV8Ob0XV5mh4o2Nv1o3VVLCqdPb',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 2610,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 2432,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 15,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 2625}}
